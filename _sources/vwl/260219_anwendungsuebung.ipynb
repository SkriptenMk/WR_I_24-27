# %% [markdown]
# # Anwendungsübungen zu Markt- und Planwirtschaft

# %% [markdown]
# ## Wettbewerbsverzerrung durch Subventionen

# %% [markdown]
# **Kontext:** Preiskampf in Chinas EV-Markt.
# **Ziel:** Verstehen, wie Subventionen Marktpreise verzerren.

# %%
# --- Simulation: Preisverzerrung durch Subventionen ---
# TODO: zeigen sie mit zwei Funktionen, wie Subventionen den Markt
#       verzerren.
#       Erstellen Sie dazu einen Lineplot von zwei Kostenfunktionen (mit
#       und ohne Subventionen)

# %% [markdown]
# ## Korrelation Freiheit vs. BIP

# %% [markdown]
# **Kontext:** Überprüfung der Hypothese "Wohlstand braucht Freiheit".

# %%
import pandas as pd
import plotly.express as px

# Erweiterter Datensatz (Freedom House 2024 & IWF/World Bank 2024)
# Freedom Score: 0 (unfrei) bis 100 (frei)
data = {
    'Land': ['Schweiz', 'Norwegen', 'Schweden', 'Dänemark', 'Finnland', 
             'USA', 'Kanada', 'Deutschland', 'Australien', 'Japan', 
             'Indien', 'Brasilien', 'Argentinien', 'Südafrika', 'Türkei', 
             'Singapur', 'Katar', 'Saudi-Arabien', 'China', 'Russland', 
             'Vietnam', 'Venezuela'],
    'Freedom_Score': [96, 100, 99, 97, 100, 83, 97, 93, 95, 96, 66, 72, 85, 79, 33, 48, 25, 9, 9, 13, 19, 12],
    'BIP_pro_Kopf': [111047, 91884, 62036, 76581, 56084, 89599, 54935, 59925, 65946, 34713, 
                     2695, 10578, 13297, 6253, 13110, 94481, 71441, 35231, 13303, 14889, 4925, 3500],
    'Region': ['Europa', 'Europa', 'Europa', 'Europa', 'Europa', 'Amerika', 'Amerika', 'Europa', 
               'Ozeanien', 'Asien', 'Asien', 'Amerika', 'Amerika', 'Afrika', 'Eurasien', 'Asien', 
               'Nahost', 'Nahost', 'Asien', 'Eurasien', 'Asien', 'Amerika']
}

df = pd.DataFrame(data)

# Erstellung des interaktiven Scatter-Plots mit plotly express
